# %%
from typing import Dict,List 
def knapsak():
            
    items = {
        "guitar" :(1000, 25000),
        
        "DVD player":(1500, 1000),
        
        "wrist watch" :(100, 10000),
        
        "golden ring":(10,3000),
    }
    limit = 300
    bag_weight = 0
    bag_value = 0
    ratio = [(item,value/weight) for item, (weight,value) in items.items()]

    # print(items)
    # for item, (weight,value) in items.items():
    #     print(f"{item} : weight: {weight}, value:{value}")

    # print(ratio)
        
    #sort the ratio:
    # sorted_ratio = [ (item,ratios) for item , ratio  lambda x:x[1] reverse = False]
    sorted_ratio = sorted(ratio , key= lambda x:x[1], reverse = True)
    print(sorted_ratio)
    
    # while bag_weight <= limit:
        # for item,ratio in sorted_ratio:
            # knapsack+=ratio
            # print (f"knapsack = {knapsack}, current ratio= {ratio}")

    # once that i sorted the ratio list, i only need the name of the item .. :D
    # because, i must take as much as possible from the item since it is the most valueable 

    #what is i sort the items in the first place?
    # sorted_items = sorted(items.items(), key=lambda items:items[1][1], reverse = True)
    # print(sorted_items) #so its not gonna be helpful check the result:
    #[('guitar', (1000, 25000)), ('wrist watch', (100, 10000)), ('golden ring', (10, 3000)), ('DVD player', (1500, 1000))]

# now i want to fill the bag in this order: first check the name of the item with the highest ratio( form the sorted_ratio), 
# for example here the ring has the highest 300, means that every gram of a ring has the value of 300 so if the bags limitation
# is 300 grams. i must fill the bag with as many rings as possible,i sould keep the track of the value added to the bag as well.
# meaning, i should declare a variable named bag_value, initiate it with 0 then after the first item added to the bag i should update
# the bag_value with the value of the item.then again check the limitation of the bag, if there is still room , check the next most
# valuable item from the sorted ratio list. some times i can take only some part of an item, meaning that for  example, i
# have 30 grams free space left, the next valuable object is a 1500 grams dvd played and i must calculate the ration of that item * the 
# grams left. here for example if 30 grams is the room left for the bag and the second most valuable item is DVD player 
# with the ratio of 0.666 , i say 30 *0.666 = 40 , i add 30 grams to the wight of limitation( update it)  and update the bag_value(+40)
#as well
    item_name=[]
    # while bag_wight <= limitation:
    for item in sorted_ratio:
        item_name.append(item[0])
    print(item_name) 
        
knapsak()
# Out:
# [('golden ring', 300.0), ('wrist watch', 100.0), ('guitar', 25.0), ('DVD player', 0.6666666666666666)]
# ['golden ring', 'wrist watch', 'guitar', 'DVD player']

# %%
from typing import Dict,List 
def knapsack():
            
    items = {
        "guitar" :(1000, 25000),
        
        "DVD player":(1500, 1000),
        
        "wrist watch" :(100, 10000),
        
        "golden ring":(10,3000),
    }
    limit = 300
    bag_weight = 0
    bag_value = 0
    amount_left=0
    value_portion=0
    ratio = [(item,value/weight) for item, (weight,value) in items.items()]
    sorted_ratio = sorted(ratio , key= lambda x:x[1], reverse = True)
    item_name=[]
    for item in sorted_ratio:
        item_name.append(item[0])

    while bag_weight <= limitation:
        for name in item_name:
            if items[name][0]<= limitation:
                bag_weight += items[name][0]
                bag_value += items[name][1]
                print(f"item added: {name},:{items[name][0]} grams, ${items[name][1]},  bag_weight :{bag_weight} gram, bag_value:${bag_value}")
            else:
                amount_left = limitation - bag_weight
                value_portion = sorted_ratio...?
                # if i have a list like:
                # [("x",10),("y",20),..]
                # assuming that x,y,.. are unique in the list, if i have x or y how can i get 10,20,..?


                # If you have a list of tuples where the first element in each tuple is unique (e.g., "x" and "y")
                # and you want to retrieve the second element (e.g., 10 and 20) based on the first element, you can 
                # use a dictionary to create a mapping between the first elements (keys) and the second elements (values)
                
                
                
    knapsack()
# Out:
#   Cell In[69], line 32
#     value_portion = sorted_ratio...?
#                                 ^
# SyntaxError: invalid syntax

# %%
from typing import Dict,List 
def knapsack():
            
    items = {
        "guitar" :(1000, 25000),
        
        "DVD player":(1500, 1000),
        
        "wrist watch" :(100, 10000),
        
        "golden ring":(10,3000),
    }

    print(items)
    limitation = 300
    bag_weight = 0
    bag_value = 0
    amount_left=0
    value_portion=0
    ratio = [(item,value/weight) for item, (weight,value) in items.items()]
    sorted_ratio = sorted(ratio , key= lambda x:x[1], reverse = True)
    print(sorted_ratio)
    item_name=[]
    items_in_the_bag=0
    for item in sorted_ratio:
        item_name.append(item[0])
    dict_sorted_ratio = {key:value for key,value in sorted_ratio}
    while bag_weight <= limitation:
        for name in item_name:
            if items[name][0]<= limitation:
                
                bag_weight += items[name][0]
                bag_value += items[name][1]
                items_in_the_bag +=1
                print(f"item added: {name},:{items[name][0]} grams, ${items[name][1]},  bag_weight :{bag_weight} gram, bag_value:${bag_value}")
            else:
                left_amount = limitation - bag_weight
                if items[name][0] <= left_amount:
                    
                    bag_weight += left_amount
                    bag_value += items[name][1]
                else:
                    
                    value_portion = left_amount *items[name][1] # left_amount X next item ratio (value/weight)
                    bag_value +=  value_portion
    
    print(f"final bag value is {bag_value} and it is consists of {items_in_the_bag}")

knapsack()
# Out:
# {'guitar': (1000, 25000), 'DVD player': (1500, 1000), 'wrist watch': (100, 10000), 'golden ring': (10, 3000)}
# [('golden ring', 300.0), ('wrist watch', 100.0), ('guitar', 25.0), ('DVD player', 0.6666666666666666)]
# item added: golden ring,:10 grams, $3000,  bag_weight :10 gram, bag_value:$3000
# item added: wrist watch,:100 grams, $10000,  bag_weight :110 gram, bag_value:$13000
# item added: golden ring,:10 grams, $3000,  bag_weight :120 gram, bag_value:$4956000
# item added: wrist watch,:100 grams, $10000,  bag_weight :220 gram, bag_value:$4966000
# item added: golden ring,:10 grams, $3000,  bag_weight :230 gram, bag_value:$7049000
# item added: wrist watch,:100 grams, $10000,  bag_weight :330 gram, bag_value:$7059000
# final bag value is 6279000 and it is consists of 6

# %%
from typing import Dict,List 
def knapsack():
            
    items = {
        "guitar" :(1000, 25000),
        
        "DVD player":(1500, 1000),
        
        "wrist watch" :(100, 10000),
        
        "golden ring":(10,3000),
    }

    print(items)
    limitation = 300
    bag_weight = 0
    bag_value = 0
    amount_left=0
    value_portion=0
    ratio = [(item,value/weight) for item, (weight,value) in items.items()]
    sorted_ratio = sorted(ratio , key= lambda x:x[1], reverse = True)
    print(sorted_ratio)
    item_name=[]
    items_in_the_bag=0
    for item in sorted_ratio:
        item_name.append(item[0])
    dict_sorted_ratio = {key:value for key,value in sorted_ratio}
    while bag_weight <= limitation:
        for name in item_name:
            if items[name][0]<= limitation:
                
                bag_weight += items[name][0]
                bag_value += items[name][1]
                items_in_the_bag +=1
                print(f"item added: {name},:{items[name][0]} grams, ${items[name][1]},  bag_weight :{bag_weight} gram, bag_value:${bag_value}")
                
            else:
                left_amount = limitation - bag_weight
                if items[name][0] <= left_amount:
                    
                    bag_weight += left_amount
                    bag_value += items[name][1]
                    item_name.remove(name)

                else:
                    
                    value_portion = left_amount *items[name][1] # left_amount X next item ratio (value/weight)
                    bag_value +=  value_portion
    
    print(f"final bag value is {bag_value} and it is consists of {items_in_the_bag}")

knapsack()
# Out:
# {'guitar': (1000, 25000), 'DVD player': (1500, 1000), 'wrist watch': (100, 10000), 'golden ring': (10, 3000)}
# [('golden ring', 300.0), ('wrist watch', 100.0), ('guitar', 25.0), ('DVD player', 0.6666666666666666)]
# item added: golden ring,:10 grams, $3000,  bag_weight :10 gram, bag_value:$3000
# item added: wrist watch,:100 grams, $10000,  bag_weight :110 gram, bag_value:$7553000

# %%
from typing import Dict,List 
def knapsack():
            
    items = {
        "guitar" :(1000, 25000),
        
        "DVD player":(1500, 1000),
        
        "wrist watch" :(100, 10000),
        
        "golden ring":(10,3000),
    }

    print(f" items are: {items}")
    print("______________________________________________________________")
    limitation = 300
    bag_weight = 0
    bag_value = 0
    left_amount=0
    value_portion=0
    ratio = [(name,value/weight) for name, (weight,value) in items.items()]
    sorted_ratio = sorted(ratio , key= lambda x:x[1], reverse = True)
    print(f"sorted ratio:{sorted_ratio}")
    print("______________________________________________________________")
    item_name=[]
    items_in_the_bag=0
    for item in sorted_ratio:
        item_name.append(item[0])
    dict_sorted_ratio = {key:value for key,value in sorted_ratio}
    # while bag_weight <= limitation:
    for name in item_name:
        if (bag_weight + items[name][0]) <= limitation:
            
            bag_weight += items[name][0]
            bag_value += items[name][1]
            items_in_the_bag +=1
            print(f"item added: {name},:{items[name][0]} grams, ${items[name][1]},  bag_weight :{bag_weight} gram, bag_value:${bag_value}")
            
        else:
            left_amount = limitation - bag_weight
            value_portion = left_amount * (dict_sorted_ratio[name]) # left_amount X next item ratio (value/weight)
            bag_value +=  value_portion
            bag_weight += left_amount
            items_in_the_bag += 1
            print(f"item added: {name},:{items[name][0]} grams, ${items[name][1]},  bag_weight :{bag_weight} gram, bag_value:${bag_value}")


    print(f"the bag worths $ {bag_value} and weights {bag_weight} grams, and it is consists of {items_in_the_bag}")

knapsack()
